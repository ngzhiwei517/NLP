# %% [markdown]
# <a href="https://colab.research.google.com/github/ngzhiwei517/NLP/blob/main/Pandas_Data_Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data normalization is important in machine learning and data analysis to ensure that features contribute equally to the model.
#
#  Without it, **features with larger scales can dominate those with smaller scales**, leading to **biased or inaccurate models.**

# %% [markdown]
# ![Screenshot 2025-05-09 234254.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-05-09 234338.png](data:image/png;base64,...)

# %%
# importing packages
import pandas as pd

# create data
df = pd.DataFrame([
                   [180000, 110, 18.9, 1400],
                   [360000, 905, 23.4, 1800],
                   [230000, 230, 14.0, 1300],
                   [60000, 450, 13.5, 1500]],

                   columns=['Col A', 'Col B',
                            'Col C', 'Col D'])

# view data
display(df)
# Out:
#     Col A  Col B  Col C  Col D
# 0  180000    110   18.9   1400
# 1  360000    905   23.4   1800
# 2  230000    230   14.0   1300
# 3   60000    450   13.5   1500

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🧮 What is Maximum Absolute Scaling?
#
#
# This technique **rescales each feature (i.e., each column) to be in the range -1 to 1**. It works by dividing every value in a column by the **maximum absolute value of that column**.

# %%
# importing packages
import pandas as pd

# create data
df = pd.DataFrame([
                   [180000, 110, 18.9, 1400],
                   [360000, 905, 23.4, 1800],
                   [230000, 230, 14.0, 1300],
                   [60000, 450, 13.5, 1500]],

                   columns=['Col A', 'Col B',
                            'Col C', 'Col D'])

# view data
display(df)
# Out:
#     Col A  Col B  Col C  Col D
# 0  180000    110   18.9   1400
# 1  360000    905   23.4   1800
# 2  230000    230   14.0   1300
# 3   60000    450   13.5   1500

# %%
# copy the data
df_max_scaled = df.copy()

# apply normalization techniques
for column in df_max_scaled.columns:
    df_max_scaled[column] = df_max_scaled[column]  / df_max_scaled[column].abs().max()

# view normalized data
display(df_max_scaled)
# Out:
#       Col A     Col B     Col C     Col D
# 0  0.500000  0.121547  0.807692  0.777778
# 1  1.000000  1.000000  1.000000  1.000000
# 2  0.638889  0.254144  0.598291  0.722222
# 3  0.166667  0.497238  0.576923  0.833333

# %% [markdown]
# 🔁 The loop does this:
# Takes the first column ('Col A')
# ➤ Scales all values in 'Col A' by dividing each value by the max absolute value in that column.
#
# Moves to the second column ('Col B')
# ➤ Scales all values in 'Col B' the same way.
#
# Then to the third, and so on...

# %%
df_max_scaled.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Using The min-max feature scaling

# %% [markdown]
# The min-max approach (often called normalization) rescales the feature to a hard and fast range of [0,1] by subtracting the minimum value of the feature then dividing by the range.

# %% [markdown]
# We can apply the min-max scaling in Pandas using the .min() and .max() methods.

# %%
# copy the data
df_min_max_scaled = df.copy()

# apply normalization techniques
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())

# view normalized data
print(df_min_max_scaled)
# Out:
#       Col A     Col B     Col C  Col D
# 0  0.400000  0.000000  0.545455    0.2
# 1  1.000000  1.000000  1.000000    1.0
# 2  0.566667  0.150943  0.050505    0.0
# 3  0.000000  0.427673  0.000000    0.4

# %%
df_max_scaled.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Using The z-score method
#
# The z-score method (often called standardization) transforms the info into distribution with a mean of 0 and a typical deviation of 1.
#
#
# Each standardized value is computed by **subtracting the mean of the corresponding feature then dividing by the quality deviation.**

# %%
# copy the data
df_z_scaled = df.copy()

# apply normalization techniques
for column in df_z_scaled.columns:
    df_z_scaled[column] = (df_z_scaled[column] -
                           df_z_scaled[column].mean()) / df_z_scaled[column].std()

# view normalized data
display(df_z_scaled)
# Out:
#       Col A     Col B     Col C    Col D
# 0 -0.221422 -0.895492  0.311486 -0.46291
# 1  1.227884  1.373564  1.278167  1.38873
# 2  0.181163 -0.552993 -0.741122 -0.92582
# 3 -1.187625  0.074922 -0.848531  0.00000

# %% [markdown]
# The standardised value can be more than 1

# %%
df_z_scaled.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Summary
#
# Data normalization consists of remodeling numeric columns to a standard scale.
