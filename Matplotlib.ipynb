# %% [markdown]
# <a href="https://colab.research.google.com/github/ngzhiwei517/NLP/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  What is Matplotlib?
#
# It helps you draw graphs , bars , pie charts , and much more, so you can see your data instead of just reading boring numbers 🔢.
#
#
# Imagine you have test scores of 3 students and want to see who did best — Matplotlib can help you show that easily!

# %% [markdown]
# #  What Can You Do with Matplotlib?
# 📈 Line, bar, scatter plots
#
#
# *   Build visualizations quickly
#
#
# 🏷️ Add labels, titles, legends
#
# 📐 Resize and layout	Adjust figures for clarity
#
# 💾 Save plots	Export as PNG, PDF, SVG
#
# 🔳 Subplots	Combine multiple graphs in one figure

# %% [markdown]
# # Core Concepts
#
# Figure vs Axes
#
# Figure = entire window or image that holds the plot(s)
#
#
# Axes = the individual graph/plot inside the figure
#
# Think of it like:
#
# 🖼️ Figure = Frame
#
# 📈 Axes = Picture inside the frame

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Bar chart

# %%
import matplotlib.pyplot as plt

students = ['Alice', 'Bob', 'Charlie']
scores = [85, 92, 78]

plt.bar(students, scores,color="Salmon")
plt.xlabel('Students')
plt.ylabel('Scores')
plt.title('Test Scores')
plt.show()

# %% [markdown]
# # Adding value labels on a Matplotlib Bar Chart

# %%
#we can use plt.text to display value on the top of the bar
#plt.text(x, y, s, ha)

#s: The string (value label) to be displayed.
#ha: Horizontal alignment (‘center’, ‘left’, or ‘right’) for the label.

import matplotlib.pyplot as plt
# Data for the bar chart
x = ["Engineering", "BSc", "MBA", "Bcom", "BBA", "MSc"]
y = [9330, 4050, 3030, 5500, 8040, 4560]

# Creating bar chart
plt.bar(x, y)

# Adding title and labels
plt.title("College Admission")
plt.xlabel("Courses")
plt.ylabel("Number of Admissions")



# Function to add value labels on top of bars
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i],ha='center')  # Placing text slightly above the bar

#The i corresponds to the position (index) of each bar

add_labels(x, y)

# %% [markdown]
# # Displaying Value Labels Inside a Rectangular Box

# %%
import matplotlib.pyplot as plt

# Function to add labels inside a box
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha='center',
                 bbox=dict(facecolor='orange', alpha=0.5))  # Adding a red box around text

# Matplotlib expects the bbox parameter to be a dictionary that describes the properties of the text box.
# alpha	0.8	Sets transparency (1.0 = opaque, 0 = invisible)

x = ["Engineering", "BSc", "MBA", "Bcom", "BBA", "MSc"]
y = [9330, 4050, 3030, 5500, 8040, 4560]

# Setting figure size
plt.figure(figsize=(10, 5))

# Creating bar chart
plt.bar(x, y)

# Adding value labels
add_labels(x, y)

# Adding title and labels
plt.title("College Admission")
plt.xlabel("Courses")
plt.ylabel("Number of Admissions")

plt.show()

# %% [markdown]
# # Placing Labels at the Center of Each Bar

# %%
#i	        X-coordinate of the text — usually the center of the bar
#y[i] // 2	Y-coordinate of the text — this places it halfway up the bar

# Function to place labels at the center of each bar
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i] // 2, y[i], ha='center')  # Placing text at half the bar height


import matplotlib.pyplot as plt
x = ["Engineering", "BSc", "MBA", "Bcom", "BBA", "MSc"]
y = [9330, 4050, 3030, 5500, 8040, 4560]

# Setting figure size
plt.figure(figsize=(10, 5))

# Creating bar chart
plt.bar(x, y)

# Adding value labels
add_labels(x, y)

# Adding title and labels
plt.title("College Admission")
plt.xlabel("Courses")
plt.ylabel("Number of Admissions")

plt.show()

# %% [markdown]
# # Centered Labels Inside a Rectangular Box

# %%
#i	        X-coordinate of the text — usually the center of the bar
#y[i] // 2	Y-coordinate of the text — this places it halfway up the bar

# Function to place labels at the center of each bar
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i] // 2, y[i], ha='center',bbox=dict(facecolor='white', alpha=0.5))  # Placing text at half the bar height


import matplotlib.pyplot as plt
x = ["Engineering", "BSc", "MBA", "Bcom", "BBA", "MSc"]
y = [9330, 4050, 3030, 5500, 8040, 4560]

# Setting figure size
plt.figure(figsize=(10, 5))

# Creating bar chart
plt.bar(x, y)

# Adding value labels
add_labels(x, y)

# Adding title and labels
plt.title("College Admission")
plt.xlabel("Courses")
plt.ylabel("Number of Admissions")

plt.show()

# %% [markdown]
# # Style Plots using Matplotlib
#
# By using style function in Matplotlib we can apply predefined themes or create custom styles which helps in making our plots interactive. We can reuse these templates to maintain consistency across multiple plots.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
data = np.random.randn(50)
plt.style.use('tableau-colorblind10')
plt.plot(data)
plt.show()
# Out:
# [ 0.65114341  1.74297142  1.78977325 -0.07445234  0.17236316 -1.59260677
#  -0.89902981 -0.67058686 -0.45345811  0.5554056  -0.33253904  0.69567949
#   0.68948762  1.71931012 -2.105261   -0.89135492  0.52698294 -1.00336393
#   1.13240163 -0.09539029  0.06840065  0.68702997  0.48650535  0.31330791
#   0.56054242  0.87855512  0.1577683   2.50565149  1.19601501  1.12210565
#   0.5226471  -0.0911927   0.67476823  0.52925491  0.38305481 -1.15103967
#   0.54543175 -1.19307257  0.0405107   0.33679646 -1.14244107 -0.84265293
#  -0.45349492 -1.11043284  0.12220622 -0.56312492  0.94179291 -0.4994275
#  -2.09422626 -1.14430192]

# %% [markdown]
# # Applying dark_background Style

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
data = np.random.randn(50)
plt.style.use('dark_background')
plt.plot(data)
plt.show()

# %% [markdown]
# # Example 3: Applying ggplot Style

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
data = np.random.randn(50)
plt.style.use('ggplot')
plt.plot(data, linestyle=":", linewidth=2)
#linewidth=2 → controls the thickness of the line ✏️
plt.show()

# %% [markdown]
# # Line Chart

# %% [markdown]
# 📊 What is pyplot.plot()?
#
# The plot() function in Matplotlib's Pyplot module is used to draw line graphs, which show the relationship between two sets of values — usually one for the X-axis and one for the Y-axis.

# %%
x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Line plot of x and y")
plt.show()

# %% [markdown]
# # Matplotlib Markers
#
# The markers module in Matplotlib helps highlight individual data points on plots, improving readability
#
# Consider the following simple example where we plot a line graph with circular markers:

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 7, 11]
y2 = [1, 4, 6, 8, 10]

plt.plot(x, y1, marker='o', linestyle='-', color='r',label='Prime Numbers')
plt.plot(x, y2, marker='D', linestyle='--',color='g', label='Even Numbers')

plt.title('Sample Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()  # Displays the labels
plt.show()

# %% [markdown]
# 📌 Other Common Markers:
#
# Marker	Description	Emoji
#
# 'o'	Circle
#
# 's'	Square
#
# '^'	Triangle Up
#
# 'x'	X
#
# 'D'	Diamond
#
# '+'	Plus

# %% [markdown]
# # Visualizing Multiple Marker Shapes

# %% [markdown]
# This code generates a plot showcasing different Matplotlib markers. It iterates through a list of marker styles and displays them on the same x-axis, with each marker positioned along a horizontal line at different y-values.

# %%
import matplotlib.pyplot as plt

x = range(1, 11)
markers = ['o', 's', '^', 'v', 'D', '*', '+', 'x']

for i, marker in enumerate(markers):
    plt.plot(x, [i*2]*10, marker=marker, linestyle='')

plt.title('Different Matplotlib Markers')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# # Pie Charts
#
# Use plt.pie() instead of plt.plot().

# %%
import matplotlib.pyplot as plt
labels = ['Python', 'Java', 'C++', 'JavaScript']
sizes = [40, 30, 20, 10]
plt.pie(sizes,labels=labels, autopct='%1.2f%%')
#autopct stands for "automatic percentage" — it tells Matplotlib how to display the percentage labels on each slice of the pie char
#% → This starts a format specifier
#1.1f → Format the number as a floating point with 1 decimal
#%% → To show a literal percent sign, we type %%
plt.show()

# %% [markdown]
# # Scatter Plots

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [5, 7, 9, 11, 13]
plt.scatter(x,y)
plt.xlabel("X label")
plt.ylabel("Y label")
plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# numpy is a library for numerical operations, especially for handling arrays and random data generation.

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randn(1000)
#This line generates 1,000 random numbers from a standard normal distribution
plt.hist(data, bins=30)
#bins=30 means the data range is divided into 30 intervals (bins),
#showing how many data points fall into each interval.
plt.show()

# %% [markdown]
# # 🎨 What is a Subplot?
#
# A subplot is simply:
#
# A smaller plot (graph) within a larger figure 🖼️ — allowing you to show multiple plots in one window for comparison or layout purposes.
#
#
# 📌 Why Use Subplots?
#
# To compare data side by side 🔍
#
# To organize multiple graphs in a neat layout 📐

# %% [markdown]
# >  One of the most useful features of Matplotlib is its ability to create multiple subplots within a single figure using the plt.subplots() method.

# %% [markdown]
# This allows users to display multiple related visualizations side by side, making data analysis more insightful and effective.

# %% [markdown]
# # Change the Size of Figures using set_figheight() and set_figwidth()

# %%
import matplotlib.pyplot as plt

# values on x-axis
x = [1, 2, 3, 4, 5]
# values on y-axis
y = [1, 2, 3, 4, 5]

# naming the x and y axis
plt.xlabel('x - axis')
plt.ylabel('y - axis')

# plotting a line plot with it's default size
print("Plot in it's default size: ")
plt.plot(x, y)
plt.show()

# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(9)    # Set width to 9 inches
f.set_figheight(3)   # Set height to 1 inch


print("Plot after re-sizing: ")
plt.plot(x, y)
plt.show()
# Out:
# Plot in it's default size:
# Plot after re-sizing:

# %%
plt.figure(figsize=(9, 3))
plt.plot(x, y)
plt.title("Using figsize")
plt.show()

# %% [markdown]
# # Changing the default size of the figure by using **rcParams (runtime configuration parameters)**

# %% [markdown]
# We can permanently change the default size of a figure as per our needs by setting the figure.figsize. In this example, we are using Matplotlib to create a line plot with the default size and then adjusts the default figure size to [2, 2].

# %%
import matplotlib.pyplot as plt

# values on x-axis
x = [1, 2, 3, 4, 5]
# values on y-axis
y = [1, 2, 3, 4, 5]

# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')

# plotting a line plot with it's default size
plt.plot(x, y)
plt.show()

# changing the rc parameters and plotting a line plot
plt.rcParams['figure.figsize'] = [6, 6]

plt.plot(x, y)
plt.show()

plt.scatter(x, y)
plt.show()

# %% [markdown]
# # What are subplots in matplotlib?
#
# Subplots in Matplotlib refer to multiple plots arranged within a single figure.
#
#
# The matplotlib.pyplot.subplots() method provides an easy way to create a figure with multiple plots.
#
#
# fig, ax = plt.subplots(2, 2)
#
#
#
#
# *  plt.subplots(2, 2) creates a figure (fig) with a 2x2 grid of subplots (ax), resulting in 4 axes objects.
#
#
#
# *  ax is a 2x2 numpy array where each element is a subplot (axes object), which can be accessed like a matrix.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Creating subplots
fig, ax = plt.subplots(2, 2)

# Generating data
x = np.linspace(0, 10, 1000)
#np.linspace(0, 10, 1000) generates 1000 equally spaced points between 0 and 10.

#np.linspace(0, 10, 5)
#array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# Plot functions with different styles
ax[0, 0].plot(x, np.sin(x), 'r-.', label='sin(x)')


ax[0, 1].plot(x, np.cos(x), 'g--', label='cos(x)')
ax[1, 0].plot(x, np.tan(x), 'y-', label='tan(x)')
ax[1, 1].plot(x, np.sinc(x), 'c.-', label='sinc(x)')

# Adding legends and showing the figure
for axes in ax.flat:
    axes.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# This code creates a 2×2 grid of subplots using Matplotlib and plots different mathematical functions (sin, cos, tan, and sinc) with distinct line styles. It generates x values using NumPy and assigns each function to a specific subplot.

# %% [markdown]
# np.linspace(0, 10, 1000) means:
#
# 👉 Cut the interval from 0 to 10 into 1000 evenly spaced points
# 👉 Then use those points as the x-values

# %% [markdown]
# # Line plots in subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data for subplots
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

# Create subplots with line plots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))

axes[0].plot(x, y1, color='blue', label='sin(x)')
axes[1].plot(x, y2, color='green', label='cos(x)')
axes[2].plot(x, y3, color='orange', label='tan(x)')

# Add titles and legends
axes[0].set_title('Sine Function')
axes[1].set_title('Cosine Function')
axes[2].set_title('Tangent Function')

for ax in axes:
    ax.legend()

# Adjust layout for better spacing
plt.tight_layout()

# Display the figure
plt.show()

# %% [markdown]
# Explanation: This code creates a single-row, three-column subplot layout using Matplotlib, plotting sin(x), cos(x) and tan(x) with distinct colors.
